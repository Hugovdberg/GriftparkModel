# %%
# Importing packages
from pathlib import Path  # Filepath maniputlation

import fiona
import flopy  # MODFLOW interface for Python
import gstools  # GeoStat-tools
import matplotlib.path as mpth
import matplotlib.pyplot as plt  # Plotting
import numpy as np  # Numeric array manipulation
import scipy.ndimage as si  # Numpy array manipulation
import pandas as pd

import config
from utils import (
    StressPeriod,  # Local utility functions and definitions
    stress_period_dtype,
)
# Out:
# flopy is installed in /home/hugo/.local/share/virtualenvs/Project-pEysIiSA/lib/python3.7/site-packages/flopy
# Executable file found: /home/hugo/Documenten/Studie/GEO4-1432 Environmental Hydrogeology/Project/bin/linux/mf2005
# Executable file found: /home/hugo/Documenten/Studie/GEO4-1432 Environmental Hydrogeology/Project/bin/linux/mp7
# Executable file found: /home/hugo/Documenten/Studie/GEO4-1432 Environmental Hydrogeology/Project/bin/linux/mt3dms
# Executable file found: /home/hugo/Documenten/Studie/GEO4-1432 Environmental Hydrogeology/Project/bin/linux/mf6
# Executable file found: /home/hugo/Documenten/Studie/GEO4-1432 Environmental Hydrogeology/Project/bin/linux/mt3dusgs

# %%
def run_flow_model():
    # Extract tops and bottoms from the layer boundaries (defined outside
    # function), and interpolate layers to sublayers for random field generation.
    top = layer_boundaries[0]
    bottoms = np.hstack(
        [
            np.linspace(u, l, n + 1)[1:]
            for u, l, n in zip(layer_boundaries[:-1], layer_boundaries[1:], n_sublayers)
        ]
    )

    # Convert stress period list (defined outside function) to recarray for easy
    # data extraction.
    stress_periods_ = np.array(stress_periods, dtype=stress_period_dtype)

    # Extract number of layers, columns, rows and stress periods
    n_layers = bottoms.size
    n_cols = col_width.size
    n_rows = row_height.size
    n_stress_periods = stress_periods_.size

    # Setup basic model, including reference location for spatial projections
    mf = flopy.modflow.Modflow(
        modelname=modelname,
        version="mf2005",
        exe_name=config.mfexe,
        model_ws=model_workspace,
        xul=model_extent["X"][0],
        yul=model_extent["Y"][1],
        proj4_str="EPSG:28992",
    )
    # Setup numeric discretisation (DIS package) using data collected above
    dis = flopy.modflow.ModflowDis(
        model=mf,
        nlay=n_layers,
        nrow=n_rows,
        ncol=n_cols,
        nper=n_stress_periods,
        itmuni=4,
        lenuni=2,
        delr=col_width,
        delc=row_height,
        top=top,
        botm=bottoms,
        perlen=stress_periods_["period_length"],
        nstp=stress_periods_["n_steps"],
        tsmult=stress_periods_["step_multiplier"],
        steady=stress_periods_["steady_state"],
        xul=model_extent["X"][0],
        yul=model_extent["Y"][1],
        proj4_str="+init=epsg:28992",
        start_datetime=f"4/1/{startjaar}",
    )

    # # Get node coordinates and volumes for random field generation.
    _, _, node_z = dis.get_node_coordinates()
    node_vol = dis.get_cell_volumes()
    node_x = np.tile(x, (len(node_z), 1, 1))
    node_y = np.tile(y, (len(node_z), 1, 1))

    # Setup the IBOUND and STRT arrays
    ibound = np.ones((dis.nlay, dis.nrow, dis.ncol), dtype=np.int)
    init_head = np.zeros_like(ibound, dtype=np.float)

    # Broadcast ibounds of first and second aquifer to corresponding layers
    ibound = ibounds[(wvp - 1)].astype(np.int)
    # Set the constant head at the top of the first and bottom of the second
    # aquifer.
    for r, c in zip(*np.where(const_heads[0])):
        ibound[0, r, c] = -1
        if y[r, c] < 456_750:
            init_head[0, r, c] = 0.25
    for r, c in zip(*np.where(const_heads[1])):
        ibound[-1, r, c] = -1
        if x[r, c] < 137_600:
            init_head[-1, r, c] = -0.25

    # Setup the basic flow (BAS package)
    bas = flopy.modflow.ModflowBas(model=mf, ibound=ibound, strt=init_head)

    # Generate random fields for hydraulic conductivity (data now based purely
    # on random mean and variance)
    # model_layer_1 = gstools.Gaussian(dim=3, var=1, len_scale=[50, 50, 5])
    # model_layer_2 = gstools.Gaussian(dim=3, var=2, len_scale=[40, 40, 3])

    # srf_layer_1 = gstools.SRF(model=model_layer_1, mean=25, upscaling="coarse_graining")
    # srf_layer_2 = gstools.SRF(model=model_layer_2, mean=35, upscaling="coarse_graining")

    # field_layer_1 = srf_layer_1(
    #     pos=(node_x[:5].ravel(), node_y[:5].ravel(), node_z[:5].ravel()),
    #     seed=seed(),
    #     point_volumes=node_vol[:5].ravel(),
    # )
    # field_layer_1 = np.reshape(field_layer_1, node_x[:5].shape)
    # field_layer_2 = srf_layer_2(
    #     pos=(node_x[5:].ravel(), node_y[5:].ravel(), node_z[5:].ravel()),
    #     seed=seed(),
    #     point_volumes=node_vol[5:].ravel(),
    # )
    # field_layer_2 = np.reshape(field_layer_1, node_x[5:].shape)
    # horizontal_conductivity[:5] = field_layer_1
    # horizontal_conductivity[5:] = field_layer_2
    # Set vertical conductivity to one tenth of the horizontal conductivity in
    # every node.
    # vertical_conductivity = horizontal_conductivity / 10
    horizontal_conductivity = (
        kh_buiten[:, np.newaxis, np.newaxis] * ~inside_wall[np.newaxis, :]
    )
    horizontal_conductivity += (
        kh_park[:, np.newaxis, np.newaxis] * inside_wall[np.newaxis, :]
    )
    vertical_conductivity = (
        kv_buiten[:, np.newaxis, np.newaxis] * ~inside_wall[np.newaxis, :]
    )
    vertical_conductivity += (
        kv_park[:, np.newaxis, np.newaxis] * inside_wall[np.newaxis, :]
    )

    # Setup the Layer Property Flow properties (LPF package)
    lpf = flopy.modflow.ModflowLpf(
        model=mf, hk=horizontal_conductivity, vka=vertical_conductivity
    )

    hfb = flopy.modflow.ModflowHfb(model=mf, nphfb=0, nacthfb=0, hfb_data=hfb_data)

    welldata = flopy.modflow.ModflowWel.get_empty(ncells=len(wells) * dis.nlay)
    wellflux = -10 * 24 / len(wells)
    w = 0
    z_top = -21
    z_bot = -43
    for well in wells:
        r, c = dis.get_rc_from_node_coordinates(*well, local=False)
        l_top = dis.get_layer(r, c, z_top)
        l_bot = dis.get_layer(r, c, z_bot)
        kD = np.array(
            [
                horizontal_conductivity[l, r, c]
                * (min(dis.botm[l - 1, r, c], z_top) - max(dis.botm[l, r, c], z_bot))
                for l in range(l_top, l_bot + 1)
            ]
        )
        for il, l in enumerate(range(l_top, l_bot + 1)):
            welldata[w]["k"] = l
            welldata[w]["i"] = r
            welldata[w]["j"] = c
            welldata[w]["flux"] = wellflux * kD[il] / kD.sum()
            w += 1
    welldata = welldata[:w]
    first_year = np.where(nov.index == startjaar)[0][0]
    wel = flopy.modflow.ModflowWel(model=mf, stress_period_data={first_year: welldata})

    # Setup recharge (RCH package) using a time dependent recharge rate.
    # Add recharge only to active cells of the top aquifer
    recharge = {j: ibounds[0] * n / 1000 / 365 for j, n in enumerate(nov["NOV"])}
    rch = flopy.modflow.ModflowRch(model=mf, rech=recharge)

    # Setup the output control (OC package), saving heads and budgets for all
    # timesteps in all stress periods
    oc_spd = {
        (p, sp["n_steps"] - 1): ["SAVE HEAD", "SAVE BUDGET"]
        for p, sp in enumerate(stress_periods_)
    }
    oc = flopy.modflow.ModflowOc(model=mf, stress_period_data=oc_spd)
    oc.reset_budgetunit()

    # Setup link to MT3DMS
    lnk = flopy.modflow.ModflowLmt(model=mf)

    # Setup MODFLOW solver (Preconditioned Conjugate-Gradient, PCG package)
    solver = flopy.modflow.ModflowGmg(model=mf)

    # Write MODFLOW input files to disk and run MODFLOW executable
    mf.write_input()
    mf.run_model()
    return mf


def run_transport(mf):
    mt = flopy.mt3d.Mt3dms(
        modelname=f"{modelname}_mt",
        modflowmodel=mf,
        version="mt3d-usgs",
        exe_name=config.mtusgsexe,
        model_ws=model_workspace,
    )

    icbund = np.abs(mf.bas6.ibound.array)
    init_conc_cyanide = np.zeros((mf.dis.nlay, mf.dis.nrow, mf.dis.ncol), dtype=np.float)
    init_conc_cyanide[0, :, :] += inside_wall * 100.0
    # init_sorb_conc_cyanide = np.zeros_like(init_conc_cyanide)
    Kd_cyanide = 9.9
    init_conc_PAH = np.zeros_like(init_conc_cyanide)
    init_conc_PAH[0, :, :] += inside_wall * 100.0
    # init_sorb_conc_PAH = np.zeros_like(init_conc_cyanide)
    Kd_PAH = (
        10
        ** (
            np.array([3.3, 4.4, 5.2, 5.0, 5.0, 5.6, 5.2, 5.8, 5.9, 5.8, 4.6, 5.1, 4.7])
        ).mean()
        / 1e3
        / 1e6
    )
    btn = flopy.mt3d.Mt3dBtn(
        model=mt,
        prsity=0.30,
        ncomp=2,
        mcomp=2,
        icbund=icbund,
        species_names=["Cyanide", "PAH"],
        sconc=init_conc_cyanide,
        sconc2=init_conc_PAH,
    )
    adv = flopy.mt3d.Mt3dAdv(model=mt, mixelm=-1)
    dsp = flopy.mt3d.Mt3dDsp(model=mt, al=0.1, dmcoef=0, dmcoef2=0, trpt=0.1, trpv=0.01)
    rct = flopy.mt3d.Mt3dRct(
        model=mt,
        isothm=1,
        rhob=1800,
        igetsc=0,
        srconc=0,
        srconc2=0,
        sp1=Kd_cyanide,
        sp12=Kd_PAH,
        sp2=0,
        sp22=0,
        rc1=0,
        rc12=0,
        rc2=0,
        rc22=0,
    )
    ssm = flopy.mt3d.Mt3dSsm(model=mt, crch=0, crch2=0)

    gcg = flopy.mt3d.Mt3dGcg(model=mt)
    
    for f in model_workspace.glob('MT3D*.UCN'):
        f.unlink()
    for f in model_workspace.glob('MT3D*.MAS'):
        f.unlink()

    mt.write_input()
    mt.run_model()
    return mt

# %%
# Name and location
modelname = "Griftpark"
model_workspace = Path(modelname)
model_output_dir = Path("output")
if not model_output_dir.exists():
    model_output_dir.mkdir()

layer_boundaries = [2.5, -2.5, -7.5, -32.5, -50, -60, -100]
n_sublayers = [1, 2, 10, 7, 4, 5]
wvp = np.repeat([1, 1, 1, 1, 2, 2], n_sublayers)
kh_park = np.repeat([10, 20, 80, 40, 1, 50], n_sublayers)
kh_buiten = np.repeat([1, 20, 80, 40, 1, 50], n_sublayers)
kv_park = np.repeat([1, 2, 8, 4, 10 / 100, 5], n_sublayers)
kv_buiten = np.repeat([0.1, 2, 8, 4, 10 / 2000, 5], n_sublayers)

x_zones = [136600, 137000, 137090, 137350, 137450, 138000]
ncol_zones = [8, 9, 26, 10, 11]
y_zones = [455600, 456550, 456670, 457170, 457250, 458200]
nrow_zones = [19, 12, 50, 8, 19]

model_extent = np.array(
    [(min(x_zones), min(y_zones)), (max(x_zones), max(y_zones))],
    dtype=[("X", np.float), ("Y", np.float)],
)

x_vertices = np.unique(
    np.hstack(
        [
            np.linspace(x0, x1, nc + 1)
            for x0, x1, nc in zip(x_zones[:-1], x_zones[1:], ncol_zones)
        ]
    )
)
col_width = np.diff(x_vertices)
x = x_vertices[:-1] + col_width / 2
y_vertices = np.unique(
    np.hstack(
        [
            np.linspace(y0, y1, nr + 1)
            for y0, y1, nr in zip(y_zones[:-1], y_zones[1:], nrow_zones)
        ]
    )
)[::-1]
row_height = -np.diff(y_vertices)
y = y_vertices[1:] + row_height / 2
x, y = np.meshgrid(x, y)

nov = pd.read_csv("data/neerslagoverschot.csv", index_col=0)
startjaar = 2019
nov.loc[startjaar, "NOV"] = nov.loc[nov.index <= startjaar, "NOV"].mean()
nov = nov.loc[startjaar:]
# stress_periods = [
#     StressPeriod(
#         period_length=(pd.Timestamp(f"{j+1}0401") - pd.Timestamp(f"{j}0401")).days,
#         n_steps=(j == startjaar) + 12 * (j > startjaar),
#         step_multiplier=1,
#         steady_state=j == nov.index[0],
#     )
#     for j in nov.index
# ]
stress_periods = [
    StressPeriod(
        period_length=30 * 365, n_steps=1, step_multiplier=1, steady_state=True
    )
]

with fiona.open("data/h1.shp") as isohead:
    contours_h1 = [f for f in isohead.filter(bbox=tuple(model_extent.view(np.float)))]
with fiona.open("data/h2.shp") as isohead:
    contours_h2 = [f for f in isohead.filter(bbox=tuple(model_extent.view(np.float)))]

with fiona.open("data/aquifers.shp") as src:
    aquifers = list(src)

ibounds = np.ones((len(aquifers), *x.shape), dtype=np.bool)
const_heads = np.ones((len(aquifers), *x.shape), dtype=np.bool)
for ia, aq in enumerate(aquifers):
    aq_path = mpth.Path(aq["geometry"]["coordinates"][0])
    inside_aq = aq_path.contains_points(np.vstack((x.ravel(), y.ravel())).T)
    inside_aq = np.reshape(inside_aq, x.shape)
    ibounds[ia] = inside_aq
    const_heads[ia] = ~inside_aq & ~si.binary_erosion(~inside_aq, border_value=False)

seed = gstools.random.MasterRNG(20190517)

with fiona.open("data/location_wells.shp", "r") as wellshp:
    wells = [f["geometry"]["coordinates"] for f in wellshp]

with fiona.open("data/resistive_wall.shp", "r") as shapefile:
    wall = [f["geometry"] for f in shapefile]

wall_path = mpth.Path(wall[0]["coordinates"][0])
inside_wall = wall_path.contains_points(np.vstack((x.ravel(), y.ravel())).T)
inside_wall = np.reshape(inside_wall, x.shape)

wall_mask = inside_wall & ~si.binary_erosion(inside_wall, border_value=False)
wall_mask_row, wall_mask_col = np.where(wall_mask)

hfb_conductance = 1 / 1000
hfb_data = []
for r, c in zip(wall_mask_row, wall_mask_col):
    if c == min(wall_mask_col[wall_mask_row == r]):
        # West boundary
        for l in range(5):
            hfb_data.append([l, r, c - 1, r, c, hfb_conductance])
    if c == max(wall_mask_col[wall_mask_row == r]):
        # East boundary
        for l in range(5):
            hfb_data.append([l, r, c, r, c + 1, hfb_conductance])
    if r == min(wall_mask_row[wall_mask_col == c]):
        # North boundary
        for l in range(5):
            hfb_data.append([l, r - 1, c, r, c, hfb_conductance])
    if r == max(wall_mask_row[wall_mask_col == c]):
        # South boundary
        for l in range(5):
            hfb_data.append([l, r - 1, c, r, c, hfb_conductance])

# %%
mf = run_flow_model()
mt = run_transport(mf)
# Out:
# FloPy is using the following  executable to run the model: /home/hugo/Documenten/Studie/GEO4-1432 Environmental Hydrogeology/Project/bin/linux/mf2005
#
#                                   MODFLOW-2005
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 1.12.00 2/3/2017
#
#  Using NAME file: Griftpark.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2019/06/01 21:30:06
#
#  Solving:  Stress period:     1    Time step:     1    Ground-Water Flow Eqn.
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2019/06/01 21:30:06
#  Elapsed run time:  0.852 Seconds
#
#   Normal termination of simulation
# FloPy is using the following  executable to run the model: /home/hugo/Documenten/Studie/GEO4-1432 Environmental Hydrogeology/Project/bin/linux/mt3dusgs
#
#  MT3D-USGS - Modular 3D Multi-Species Transport Model [Ver 1.00.00]
#  and based on MT3DMS. MT3D-USGS developed in cooperation by
#  S.S. Papadopulos & Associates and the U.S. Geological Survey
#
#  Using NAME File: Griftpark_mt.nam
#
#  STRESS PERIOD NO.    1
#
#  TIME STEP NO.    1
#  FROM TIME =   0.0000     TO    10950.
#
#  Transport Step:    1   Step Size:   11.19     Total Elapsed Time:   11.191
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3218E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   67   24
#  Transport Step:    2   Step Size:   11.19     Total Elapsed Time:   22.383
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3104E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   61   19
#  Transport Step:    3   Step Size:   11.19     Total Elapsed Time:   33.574
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2989E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   37
#  Transport Step:    4   Step Size:   11.19     Total Elapsed Time:   44.766
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2874E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   31
#  Transport Step:    5   Step Size:   11.19     Total Elapsed Time:   55.957
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2760E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    3   76   32
#  Transport Step:    6   Step Size:   11.19     Total Elapsed Time:   67.149
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2646E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   75   38
#  Transport Step:    7   Step Size:   11.19     Total Elapsed Time:   78.340
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2532E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   70   26
#  Transport Step:    8   Step Size:   11.19     Total Elapsed Time:   89.532
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2418E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   50   40
#  Transport Step:    9   Step Size:   11.19     Total Elapsed Time:   100.72
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2305E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   64   21
#  Transport Step:   10   Step Size:   11.19     Total Elapsed Time:   111.91
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2192E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   67   24
#  Transport Step:   11   Step Size:   11.19     Total Elapsed Time:   123.11
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2079E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4547E-12  [K,I,J]    1   72   27
#  Transport Step:   12   Step Size:   11.19     Total Elapsed Time:   134.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1966E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9095E-12  [K,I,J]    1   49   41
#  Transport Step:   13   Step Size:   11.19     Total Elapsed Time:   145.49
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1855E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   71   27
#  Transport Step:   14   Step Size:   11.19     Total Elapsed Time:   156.68
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1746E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4547E-12  [K,I,J]    1   65   39
#  Transport Step:   15   Step Size:   11.19     Total Elapsed Time:   167.87
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1639E-03  [K,I,J]    2   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1990E-12  [K,I,J]    4   35   30
#  Transport Step:   16   Step Size:   11.19     Total Elapsed Time:   179.06
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1574E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   70   26
#  Transport Step:   17   Step Size:   11.19     Total Elapsed Time:   190.26
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1516E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1819E-11  [K,I,J]    1   77   32
#  Transport Step:   18   Step Size:   11.19     Total Elapsed Time:   201.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1459E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   74   39
#  Transport Step:   19   Step Size:   11.19     Total Elapsed Time:   212.64
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1403E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   68   25
#  Transport Step:   20   Step Size:   11.19     Total Elapsed Time:   223.83
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1348E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   33
#  Transport Step:   21   Step Size:   11.19     Total Elapsed Time:   235.02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1293E-03  [K,I,J]    1   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4547E-12  [K,I,J]    1   52   17
#  Transport Step:   22   Step Size:   11.19     Total Elapsed Time:   246.21
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1278E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9095E-12  [K,I,J]    1   51   40
#  Transport Step:   23   Step Size:   11.19     Total Elapsed Time:   257.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1320E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   46   41
#  Transport Step:   24   Step Size:   11.19     Total Elapsed Time:   268.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1361E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4547E-12  [K,I,J]    4   40   28
#  Transport Step:   25   Step Size:   11.19     Total Elapsed Time:   279.79
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1400E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9095E-12  [K,I,J]    3   77   30
#  Transport Step:   26   Step Size:   11.19     Total Elapsed Time:   290.98
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1437E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4547E-12  [K,I,J]    4   36   30
#  Transport Step:   27   Step Size:   11.19     Total Elapsed Time:   302.17
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1472E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   50   40
#  Transport Step:   28   Step Size:   11.19     Total Elapsed Time:   313.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1506E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9095E-12  [K,I,J]    4   38   30
#  Transport Step:   29   Step Size:   11.19     Total Elapsed Time:   324.55
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1538E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   73   28
#  Transport Step:   30   Step Size:   11.19     Total Elapsed Time:   335.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1568E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   66   39
#  Transport Step:   31   Step Size:   11.19     Total Elapsed Time:   346.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1597E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9095E-12  [K,I,J]    4   35   30
#  Transport Step:   32   Step Size:   11.19     Total Elapsed Time:   358.13
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1623E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   29   30
#  Transport Step:   33   Step Size:   11.19     Total Elapsed Time:   369.32
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1649E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9095E-12  [K,I,J]    4   49   33
#  Transport Step:   34   Step Size:   11.19     Total Elapsed Time:   380.51
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1672E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9095E-12  [K,I,J]    1   43   42
#  Transport Step:   35   Step Size:   11.19     Total Elapsed Time:   391.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1694E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9095E-12  [K,I,J]    4   34   30
#  Transport Step:   36   Step Size:   11.19     Total Elapsed Time:   402.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1714E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1819E-11  [K,I,J]    4   37   31
#  Transport Step:   37   Step Size:   11.19     Total Elapsed Time:   414.09
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1733E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9095E-12  [K,I,J]    2   76   34
#  Transport Step:   38   Step Size:   11.19     Total Elapsed Time:   425.28
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1750E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   31
#  Transport Step:   39   Step Size:   11.19     Total Elapsed Time:   436.47
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1765E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   37   43
#  Transport Step:   40   Step Size:   11.19     Total Elapsed Time:   447.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1779E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   33
#  Transport Step:   41   Step Size:   11.19     Total Elapsed Time:   458.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1791E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   37
#  Transport Step:   42   Step Size:   11.19     Total Elapsed Time:   470.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1801E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   33
#  Transport Step:   43   Step Size:   11.19     Total Elapsed Time:   481.23
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1810E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   33
#  Transport Step:   44   Step Size:   11.19     Total Elapsed Time:   492.43
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1817E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   71   27
#  Transport Step:   45   Step Size:   11.19     Total Elapsed Time:   503.62
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1823E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5684E-12  [K,I,J]    5   39   27
#  Transport Step:   46   Step Size:   11.19     Total Elapsed Time:   514.81
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1827E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   33
#  Transport Step:   47   Step Size:   11.19     Total Elapsed Time:   526.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1829E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   32
#  Transport Step:   48   Step Size:   11.19     Total Elapsed Time:   537.19
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1830E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   37
#  Transport Step:   49   Step Size:   11.19     Total Elapsed Time:   548.38
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1829E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   31
#  Transport Step:   50   Step Size:   11.19     Total Elapsed Time:   559.57
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1827E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9095E-12  [K,I,J]    1   45   42
#  Transport Step:   51   Step Size:   11.19     Total Elapsed Time:   570.77
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1823E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1819E-11  [K,I,J]    4   51   36
#  Transport Step:   52   Step Size:   11.19     Total Elapsed Time:   581.96
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1818E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   71   27
#  Transport Step:   53   Step Size:   11.19     Total Elapsed Time:   593.15
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1811E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   32
#  Transport Step:   54   Step Size:   11.19     Total Elapsed Time:   604.34
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1802E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   37
#  Transport Step:   55   Step Size:   11.19     Total Elapsed Time:   615.53
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1793E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9663E-12  [K,I,J]    5   39   26
#  Transport Step:   56   Step Size:   11.19     Total Elapsed Time:   626.72
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1782E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   50   40
#  Transport Step:   57   Step Size:   11.19     Total Elapsed Time:   637.91
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1771E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   30
#  Transport Step:   58   Step Size:   11.19     Total Elapsed Time:   649.11
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1759E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1364E-11  [K,I,J]    5   39   27
#  Transport Step:   59   Step Size:   11.19     Total Elapsed Time:   660.30
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1745E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   42   42
#  Transport Step:   60   Step Size:   11.19     Total Elapsed Time:   671.49
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1731E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   32
#  Transport Step:   61   Step Size:   11.19     Total Elapsed Time:   682.68
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1716E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   33
#  Transport Step:   62   Step Size:   11.19     Total Elapsed Time:   693.87
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1700E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   50   40
#  Transport Step:   63   Step Size:   11.19     Total Elapsed Time:   705.06
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1684E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   30
#  Transport Step:   64   Step Size:   11.19     Total Elapsed Time:   716.25
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1667E-03  [K,I,J]    3   76   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1819E-11  [K,I,J]    5   38   29
#  Transport Step:   65   Step Size:   11.19     Total Elapsed Time:   727.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1686E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   37
#  Transport Step:   66   Step Size:   11.19     Total Elapsed Time:   738.64
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1716E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   42   42
#  Transport Step:   67   Step Size:   11.19     Total Elapsed Time:   749.83
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1746E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   37   43
#  Transport Step:   68   Step Size:   11.19     Total Elapsed Time:   761.02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1774E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   32
#  Transport Step:   69   Step Size:   11.19     Total Elapsed Time:   772.21
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1802E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   32
#  Transport Step:   70   Step Size:   11.19     Total Elapsed Time:   783.40
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1830E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   37   43
#  Transport Step:   71   Step Size:   11.19     Total Elapsed Time:   794.60
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1855E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   71   27
#  Transport Step:   72   Step Size:   11.19     Total Elapsed Time:   805.79
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1878E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   37
#  Transport Step:   73   Step Size:   11.19     Total Elapsed Time:   816.98
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1903E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2046E-11  [K,I,J]    5   39   26
#  Transport Step:   74   Step Size:   11.19     Total Elapsed Time:   828.17
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1925E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   36
#  Transport Step:   75   Step Size:   11.19     Total Elapsed Time:   839.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1947E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   31
#  Transport Step:   76   Step Size:   11.19     Total Elapsed Time:   850.55
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1968E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   37
#  Transport Step:   77   Step Size:   11.19     Total Elapsed Time:   861.74
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1988E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    1   75   38
#  Transport Step:   78   Step Size:   11.19     Total Elapsed Time:   872.94
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2008E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   37
#  Transport Step:   79   Step Size:   11.19     Total Elapsed Time:   884.13
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2025E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   36
#  Transport Step:   80   Step Size:   11.19     Total Elapsed Time:   895.32
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2042E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   36
#  Transport Step:   81   Step Size:   11.19     Total Elapsed Time:   906.51
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2058E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   30
#  Transport Step:   82   Step Size:   11.19     Total Elapsed Time:   917.70
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2074E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    2   50   40
#  Transport Step:   83   Step Size:   11.19     Total Elapsed Time:   928.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2086E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   73   28
#  Transport Step:   84   Step Size:   11.19     Total Elapsed Time:   940.08
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2102E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   36
#  Transport Step:   85   Step Size:   11.19     Total Elapsed Time:   951.28
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2115E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   35
#  Transport Step:   86   Step Size:   11.19     Total Elapsed Time:   962.47
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2128E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   46   41
#  Transport Step:   87   Step Size:   11.19     Total Elapsed Time:   973.66
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2137E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   30
#  Transport Step:   88   Step Size:   11.19     Total Elapsed Time:   984.85
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2151E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   54   39
#  Transport Step:   89   Step Size:   11.19     Total Elapsed Time:   996.04
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2161E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   36
#  Transport Step:   90   Step Size:   11.19     Total Elapsed Time:   1007.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2155E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   37
#  Transport Step:   91   Step Size:   11.19     Total Elapsed Time:   1018.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2143E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   36
#  Transport Step:   92   Step Size:   11.19     Total Elapsed Time:   1029.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2129E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    5   36   29
#  Transport Step:   93   Step Size:   11.19     Total Elapsed Time:   1040.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2118E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   50   40
#  Transport Step:   94   Step Size:   11.19     Total Elapsed Time:   1052.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2105E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   42   42
#  Transport Step:   95   Step Size:   11.19     Total Elapsed Time:   1063.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2089E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   36
#  Transport Step:   96   Step Size:   11.19     Total Elapsed Time:   1074.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2075E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    2   29   30
#  Transport Step:   97   Step Size:   11.19     Total Elapsed Time:   1085.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2063E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   54   39
#  Transport Step:   98   Step Size:   11.19     Total Elapsed Time:   1096.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2050E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   37
#  Transport Step:   99   Step Size:   11.19     Total Elapsed Time:   1108.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2035E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   66   39
#  Transport Step:  100   Step Size:   11.19     Total Elapsed Time:   1119.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2024E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   29   33
#  Transport Step:  101   Step Size:   11.19     Total Elapsed Time:   1130.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2008E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   31
#  Transport Step:  102   Step Size:   11.19     Total Elapsed Time:   1141.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1994E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   30
#  Transport Step:  103   Step Size:   11.19     Total Elapsed Time:   1152.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1979E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    5   36   28
#  Transport Step:  104   Step Size:   11.19     Total Elapsed Time:   1163.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1966E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   77   30
#  Transport Step:  105   Step Size:   11.19     Total Elapsed Time:   1175.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1952E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    3   77   32
#  Transport Step:  106   Step Size:   11.19     Total Elapsed Time:   1186.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1938E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   77   33
#  Transport Step:  107   Step Size:   11.19     Total Elapsed Time:   1197.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1923E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    4   76   34
#  Transport Step:  108   Step Size:   11.19     Total Elapsed Time:   1208.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1907E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    4   76   34
#  Transport Step:  109   Step Size:   11.19     Total Elapsed Time:   1219.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1893E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    4   76   34
#  Transport Step:  110   Step Size:   11.19     Total Elapsed Time:   1231.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1879E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    4   76   34
#  Transport Step:  111   Step Size:   11.19     Total Elapsed Time:   1242.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1863E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   77   33
#  Transport Step:  112   Step Size:   11.19     Total Elapsed Time:   1253.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1848E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3638E-11  [K,I,J]    1   76   37
#  Transport Step:  113   Step Size:   11.19     Total Elapsed Time:   1264.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1835E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    1   77   33
#  Transport Step:  114   Step Size:   11.19     Total Elapsed Time:   1275.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1819E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3752E-11  [K,I,J]    6   39   26
#  Transport Step:  115   Step Size:   11.19     Total Elapsed Time:   1287.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1804E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3865E-11  [K,I,J]    6   39   26
#  Transport Step:  116   Step Size:   11.19     Total Elapsed Time:   1298.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1790E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4093E-11  [K,I,J]    6   39   26
#  Transport Step:  117   Step Size:   11.19     Total Elapsed Time:   1309.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1775E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4320E-11  [K,I,J]    6   39   26
#  Transport Step:  118   Step Size:   11.19     Total Elapsed Time:   1320.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1760E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    6   76   33
#  Transport Step:  119   Step Size:   11.19     Total Elapsed Time:   1331.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1742E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    6   76   33
#  Transport Step:  120   Step Size:   11.19     Total Elapsed Time:   1343.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1730E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    6   76   33
#  Transport Step:  121   Step Size:   11.19     Total Elapsed Time:   1354.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1715E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    6   76   33
#  Transport Step:  122   Step Size:   11.19     Total Elapsed Time:   1365.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1701E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    6   76   31
#  Transport Step:  123   Step Size:   11.19     Total Elapsed Time:   1376.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1684E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7276E-11  [K,I,J]    6   76   31
#  Transport Step:  124   Step Size:   11.19     Total Elapsed Time:   1387.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1668E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    6   76   33
#  Transport Step:  125   Step Size:   11.19     Total Elapsed Time:   1398.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1653E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    6   76   33
#  Transport Step:  126   Step Size:   11.19     Total Elapsed Time:   1410.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1639E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    6   76   33
#  Transport Step:  127   Step Size:   11.19     Total Elapsed Time:   1421.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1624E-03  [K,I,J]    2   76   30
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    6   76   33
#  Transport Step:  128   Step Size:   11.19     Total Elapsed Time:   1432.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1608E-03  [K,I,J]    2   76   31
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    6   76   33
#  Transport Step:  129   Step Size:   11.19     Total Elapsed Time:   1443.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1595E-03  [K,I,J]    2   39   28
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    6   76   31
#  Transport Step:  130   Step Size:   11.19     Total Elapsed Time:   1454.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1599E-03  [K,I,J]    2   39   28
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2910E-10  [K,I,J]    6   76   33
#  Transport Step:  131   Step Size:   11.19     Total Elapsed Time:   1466.1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1602E-03  [K,I,J]    2   39   28
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    6   76   31
#  Transport Step:  132   Step Size:   11.19     Total Elapsed Time:   1477.3
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1605E-03  [K,I,J]    2   39   28
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    6   76   31
#  Transport Step:  133   Step Size:   11.19     Total Elapsed Time:   1488.5
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1606E-03  [K,I,J]    2   39   28
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2910E-10  [K,I,J]    6   76   33
#  Transport Step:  134   Step Size:   11.19     Total Elapsed Time:   1499.7
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1608E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    6   76   30
#  Transport Step:  135   Step Size:   11.19     Total Elapsed Time:   1510.9
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1609E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    6   76   30
#  Transport Step:  136   Step Size:   11.19     Total Elapsed Time:   1522.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1611E-03  [K,I,J]    2   39   28
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2910E-10  [K,I,J]    6   76   32
#  Transport Step:  137   Step Size:   11.19     Total Elapsed Time:   1533.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1613E-03  [K,I,J]    2   39   28
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    6   76   30
#  Transport Step:  138   Step Size:   11.19     Total Elapsed Time:   1544.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1609E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6821E-11  [K,I,J]    6   39   26
#  Transport Step:  139   Step Size:   11.19     Total Elapsed Time:   1555.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1593E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6821E-11  [K,I,J]    6   39   26
#  Transport Step:  140   Step Size:   11.19     Total Elapsed Time:   1566.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1576E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2910E-10  [K,I,J]    6   76   31
#  Transport Step:  141   Step Size:   11.19     Total Elapsed Time:   1578.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1555E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6366E-11  [K,I,J]    6   39   26
#  Transport Step:  142   Step Size:   11.19     Total Elapsed Time:   1589.2
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1540E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    4   77   32
#  Transport Step:  143   Step Size:   11.19     Total Elapsed Time:   1600.4
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1521E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    4   77   32
#  Transport Step:  144   Step Size:   11.19     Total Elapsed Time:   1611.6
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1503E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    4   77   32
#  Transport Step:  145   Step Size:   11.19     Total Elapsed Time:   1622.8
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1486E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    4   77   32
#  Transport Step:  146   Step Size:   11.19     Total Elapsed Time:   1634.0
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1469E-03  [K,I,J]    2   39   29
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1455E-10  [K,I,J]    4   77   32
#  Transport Step:  147   Step Size:   11.19     Total Elapsed Time:   1645.2
# ...
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1819      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1469E-05  [K,I,J]    9   50   36
#  Transport Step:  931   Step Size:   11.19     Total Elapsed Time:   10419.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1816      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1465E-05  [K,I,J]    9   50   36
#  Transport Step:  932   Step Size:   11.19     Total Elapsed Time:   10430.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1812      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1462E-05  [K,I,J]    9   50   36
#  Transport Step:  933   Step Size:   11.19     Total Elapsed Time:   10442.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1809      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1459E-05  [K,I,J]    9   50   36
#  Transport Step:  934   Step Size:   11.19     Total Elapsed Time:   10453.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1806      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1456E-05  [K,I,J]    9   50   36
#  Transport Step:  935   Step Size:   11.19     Total Elapsed Time:   10464.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1803      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1452E-05  [K,I,J]    9   50   36
#  Transport Step:  936   Step Size:   11.19     Total Elapsed Time:   10475.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1799      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1449E-05  [K,I,J]    9   50   36
#  Transport Step:  937   Step Size:   11.19     Total Elapsed Time:   10486.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1796      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1446E-05  [K,I,J]    9   50   36
#  Transport Step:  938   Step Size:   11.19     Total Elapsed Time:   10498.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1793      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1443E-05  [K,I,J]    9   50   36
#  Transport Step:  939   Step Size:   11.19     Total Elapsed Time:   10509.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1789      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1440E-05  [K,I,J]    9   50   36
#  Transport Step:  940   Step Size:   11.19     Total Elapsed Time:   10520.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1786      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1437E-05  [K,I,J]    9   50   36
#  Transport Step:  941   Step Size:   11.19     Total Elapsed Time:   10531.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1783      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1434E-05  [K,I,J]    9   50   36
#  Transport Step:  942   Step Size:   11.19     Total Elapsed Time:   10542.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1779      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1431E-05  [K,I,J]    9   50   36
#  Transport Step:  943   Step Size:   11.19     Total Elapsed Time:   10554.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1776      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1427E-05  [K,I,J]    9   50   36
#  Transport Step:  944   Step Size:   11.19     Total Elapsed Time:   10565.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1773      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1424E-05  [K,I,J]    9   50   36
#  Transport Step:  945   Step Size:   11.19     Total Elapsed Time:   10576.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1770      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1421E-05  [K,I,J]    9   50   36
#  Transport Step:  946   Step Size:   11.19     Total Elapsed Time:   10587.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1766      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1418E-05  [K,I,J]    9   50   36
#  Transport Step:  947   Step Size:   11.19     Total Elapsed Time:   10598.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1763      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1415E-05  [K,I,J]    9   50   36
#  Transport Step:  948   Step Size:   11.19     Total Elapsed Time:   10609.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1760      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1413E-05  [K,I,J]    9   50   36
#  Transport Step:  949   Step Size:   11.19     Total Elapsed Time:   10621.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1757      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1410E-05  [K,I,J]    9   50   36
#  Transport Step:  950   Step Size:   11.19     Total Elapsed Time:   10632.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1753      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1407E-05  [K,I,J]    9   50   36
#  Transport Step:  951   Step Size:   11.19     Total Elapsed Time:   10643.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1750      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1404E-05  [K,I,J]    9   50   36
#  Transport Step:  952   Step Size:   11.19     Total Elapsed Time:   10654.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1747      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1401E-05  [K,I,J]    9   50   36
#  Transport Step:  953   Step Size:   11.19     Total Elapsed Time:   10665.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1744      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1398E-05  [K,I,J]    9   50   36
#  Transport Step:  954   Step Size:   11.19     Total Elapsed Time:   10677.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1741      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1395E-05  [K,I,J]    9   50   36
#  Transport Step:  955   Step Size:   11.19     Total Elapsed Time:   10688.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1737      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1392E-05  [K,I,J]    9   50   36
#  Transport Step:  956   Step Size:   11.19     Total Elapsed Time:   10699.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1734      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1389E-05  [K,I,J]    9   50   36
#  Transport Step:  957   Step Size:   11.19     Total Elapsed Time:   10710.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1731      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1386E-05  [K,I,J]    9   50   36
#  Transport Step:  958   Step Size:   11.19     Total Elapsed Time:   10721.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1728      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1383E-05  [K,I,J]    9   50   36
#  Transport Step:  959   Step Size:   11.19     Total Elapsed Time:   10733.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1725      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1381E-05  [K,I,J]    9   50   36
#  Transport Step:  960   Step Size:   11.19     Total Elapsed Time:   10744.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1722      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1378E-05  [K,I,J]    9   50   36
#  Transport Step:  961   Step Size:   11.19     Total Elapsed Time:   10755.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1719      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1375E-05  [K,I,J]    9   50   36
#  Transport Step:  962   Step Size:   11.19     Total Elapsed Time:   10766.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1716      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1372E-05  [K,I,J]    9   50   36
#  Transport Step:  963   Step Size:   11.19     Total Elapsed Time:   10777.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1713      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1369E-05  [K,I,J]    9   50   36
#  Transport Step:  964   Step Size:   11.19     Total Elapsed Time:   10789.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1710      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1367E-05  [K,I,J]    9   50   36
#  Transport Step:  965   Step Size:   11.19     Total Elapsed Time:   10800.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1707      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1364E-05  [K,I,J]    9   50   36
#  Transport Step:  966   Step Size:   11.19     Total Elapsed Time:   10811.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1703      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1361E-05  [K,I,J]    9   50   36
#  Transport Step:  967   Step Size:   11.19     Total Elapsed Time:   10822.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1700      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1357E-05  [K,I,J]    9   50   36
#  Transport Step:  968   Step Size:   11.19     Total Elapsed Time:   10833.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1697      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1354E-05  [K,I,J]    9   50   36
#  Transport Step:  969   Step Size:   11.19     Total Elapsed Time:   10844.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1693      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1351E-05  [K,I,J]    9   50   36
#  Transport Step:  970   Step Size:   11.19     Total Elapsed Time:   10856.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1690      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1348E-05  [K,I,J]    9   50   36
#  Transport Step:  971   Step Size:   11.19     Total Elapsed Time:   10867.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1687      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1345E-05  [K,I,J]    9   50   36
#  Transport Step:  972   Step Size:   11.19     Total Elapsed Time:   10878.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1683      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1342E-05  [K,I,J]    9   50   36
#  Transport Step:  973   Step Size:   11.19     Total Elapsed Time:   10889.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1680      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1339E-05  [K,I,J]    9   50   36
#  Transport Step:  974   Step Size:   11.19     Total Elapsed Time:   10900.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1677      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1336E-05  [K,I,J]    9   50   36
#  Transport Step:  975   Step Size:   11.19     Total Elapsed Time:   10912.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1673      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1332E-05  [K,I,J]    9   50   36
#  Transport Step:  976   Step Size:   11.19     Total Elapsed Time:   10923.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1670      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1329E-05  [K,I,J]    9   50   36
#  Transport Step:  977   Step Size:   11.19     Total Elapsed Time:   10934.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1667      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1326E-05  [K,I,J]    9   50   36
#  Transport Step:  978   Step Size:   11.19     Total Elapsed Time:   10945.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1663      [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1323E-05  [K,I,J]    9   50   36
#  Transport Step:  979   Step Size:   4.786     Total Elapsed Time:   10950.
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =   0.000      [K,I,J]    1    1    1
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7048E-01  [K,I,J]   12   50   35
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1313E-06  [K,I,J]    9   50   36
#
#  Program completed.   Total CPU time:  004 minutes 47.472 seconds

# %%
hds_file = flopy.utils.HeadFile(model_workspace / f"{modelname}.hds")
# heads = hds_file.get_data((11, 21))
heads = hds_file.get_data()

cbc_file = flopy.utils.CellBudgetFile(model_workspace / f"{modelname}.cbc")
frf = cbc_file.get_data(text="FLOW RIGHT FACE")[0]
fff = cbc_file.get_data(text="FLOW FRONT FACE")[0]
flf = cbc_file.get_data(text="FLOW LOWER FACE")[0]

conc_file1 = flopy.utils.UcnFile(model_workspace / f"MT3D001.UCN")
conc_file2 = flopy.utils.UcnFile(model_workspace / f"MT3D002.UCN")
sorb_conc_file2 = flopy.utils.UcnFile(model_workspace / f"MT3D002S.UCN")

# %%
conc_file1.nlay
# Out:
# 29

# %%
conc2 = conc_file2.get_alldata()

# %%
conc2_ts = conc_file2.get_ts((0, 72, 51))
sorb_conc2_ts = sorb_conc_file2.get_ts((0, 72, 51))
fig, ax = plt.subplots()
ax.plot(
    pd.to_datetime(conc2_ts[:, 0], unit="D", origin="1989-04-01").normalize(),
    conc2_ts[:, 1],
    color="blue",
)
ax2 = ax.twinx()
ax2.plot(
    pd.to_datetime(sorb_conc2_ts[:, 0], unit="D", origin="1989-04-01").normalize(),
    sorb_conc2_ts[:, 1],
    color="red",
)
plt.show()
plt.close(fig)

ts = hds_file.get_ts((0, 72, 51))
plt.plot(pd.to_datetime(ts[:, 0], unit="D", origin="1989-04-01").normalize(), ts[:, 1])
plt.close(fig)

# %%
fig, ax = plt.subplots(figsize=(16, 16))
ilay = 0
ax.set_title(f"Layer {ilay+1}")
ax.set_aspect(1)
extent = None
# extent = [137000, 137400, 456600, 457400]  # Wall
# extent = [137150, 137300, 456900, 457150]  # Wells
pmv = flopy.plot.PlotMapView(model=mf, ax=ax, layer=ilay, extent=extent)
# pmv.plot_grid(linewidths=1, alpha=0.5)
# c = pmv.plot_array(heads, alpha=1, masked_values=[-999.99])
c = pmv.plot_array(conc2[0])
# c = pmv.plot_array(horizontal_conductivity, alpha=1, masked_values=[-999.99])
# c = pmv.plot_array(ibounds[0].astype(int))  # + const_heads[1].astype(int))
plt.colorbar(c, ax=ax)
# pmv.plot_ibound()
# pmv.plot_discharge(
#     frf=frf, fff=fff, flf=flf, head=heads, color="#ffffff", istep=3, jstep=3
# )
# for contour in contours_h1:
#     points = np.array(contour["geometry"]["coordinates"])
#     ax.plot(points[:, 0], points[:, 1], "--", color="k")
# for contour in contours_h2:
#     points = np.array(contour["geometry"]["coordinates"])
#     ax.plot(points[:, 0], points[:, 1], "-.", color="k")
pmv.plot_bc("WEL", plotAll=True)
# pmv.plot_ibound()
# pmv.plot_bc("HFB6")
# pmv.plot_shapefile("data/aquifers.shp")
pmv.plot_shapefile("data/resistive_wall.shp", alpha=1, facecolor="None")
pmv.plot_shapefile("data/location_wells.shp", radius=1, edgecolor="blue", facecolor="b")
fig.tight_layout()
fig.savefig(model_output_dir / "map.png")
plt.close(fig)

fig, ax = plt.subplots(figsize=(16, 8))
ax.set_aspect(15)
# row=72, column=51
xs_line = wells
pxs = flopy.plot.PlotCrossSection(
    model=mf, ax=ax, line={"row": 51}  # , extent=(600, 800, -80, 0)
)
pxs.plot_grid(linewidths=0.5, alpha=0.5)
# pxs.plot_bc("WEL", zorder=10)
# c = pxs.plot_array(heads, head=heads, masked_values=[-999.99], vmin=-0.25, vmax=0.75)  #
c = pxs.plot_array(conc2[-1], head=heads, masked_values=[-999.99])  #
plt.colorbar(c, ax=ax)
# pxs.plot_ibound(color_noflow="#aaaaaa", head=heads)
pxs.plot_discharge(
    frf=frf,
    fff=fff,
    flf=flf,
    head=heads,
    color="#ffffff",
    normalize=True,
    hstep=3,
    kstep=2,
)
fig.tight_layout()
fig.savefig(model_output_dir / "crosssection.png")
plt.close(fig)
